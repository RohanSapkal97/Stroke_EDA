# %% [markdown]
# # EDA Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
dataset.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
dataset.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
sns.distplot(dataset.bmi)
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
dataset1 = dataset["bmi"].fillna(dataset["bmi"].median())

# %%
sns.distplot(dataset1)
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
dataset2 = dataset["bmi"].fillna(dataset["bmi"].mean())
sns.distplot(dataset2)
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
dataset1 = dataset.fillna(dataset.median())

# %%
dataset1.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
dataset1['smoking_status'].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
dataset2 = dataset1[dataset1['smoking_status'] == 'Unknown'].index
 
dataset1.drop(dataset2 , inplace=True)

# %%
dataset1['smoking_status'].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes'], dtype=object)

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3566 entries, 0 to 5108
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3566 non-null   int64
#  1   gender             3566 non-null   object
#  2   age                3566 non-null   float64
#  3   hypertension       3566 non-null   int64
#  4   heart_disease      3566 non-null   int64
#  5   ever_married       3566 non-null   object
#  6   work_type          3566 non-null   object
#  7   Residence_type     3566 non-null   object
#  8   avg_glucose_level  3566 non-null   float64
#  9   bmi                3566 non-null   float64
#  10  smoking_status     3566 non-null   object
#  11  stroke             3566 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 362.2+ KB

# %%
dataset1.duplicated().sum()
# Out:
# 0

# %%
sns.set(style='whitegrid', palette = 'muted', color_codes=True)

# %% [markdown]
# # Univariate Analysis

# %%
figure,ax = plt.subplots(figsize=(12,6))

sns.countplot(dataset1.stroke)

plt.show()
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dataset1['stroke'].value_counts()
# Out:
# 0    3364
# 1     202
# Name: stroke, dtype: int64

# %%
figure,ax = plt.subplots(figsize=(12,6))

sns.boxplot(dataset1.age, color ='r')

plt.show()
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
figure,ax = plt.subplots(figsize=(12,6))

sns.boxplot(dataset1.avg_glucose_level, color ='b')

plt.show()
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
figure,ax = plt.subplots(figsize=(12,6))

sns.boxplot(dataset1.bmi, color ='g')

plt.show()
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
figure,ax = plt.subplots(figsize=(12,6))

sns.countplot(dataset1.gender)

plt.show()
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dataset1['gender'].value_counts()
# Out:
# Female    2158
# Male      1407
# Other        1
# Name: gender, dtype: int64

# %%
dataset1['hypertension'].value_counts()
# Out:
# 0    3120
# 1     446
# Name: hypertension, dtype: int64

# %%
figure,ax = plt.subplots(figsize=(12,6))

sns.countplot(dataset1.hypertension)

plt.show()
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dataset1['heart_disease'].value_counts()
# Out:
# 0    3338
# 1     228
# Name: heart_disease, dtype: int64

# %%
figure,ax = plt.subplots(figsize=(12,6))

sns.countplot(dataset1.heart_disease)

plt.show()
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dataset1['ever_married'].value_counts()
# Out:
# Yes    2710
# No      856
# Name: ever_married, dtype: int64

# %%
figure,ax = plt.subplots(figsize=(12,6))

sns.countplot(dataset1.ever_married)

plt.show()
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dataset1['work_type'].value_counts()
# Out:
# Private          2285
# Self-employed     663
# Govt_job          535
# children           69
# Never_worked       14
# Name: work_type, dtype: int64

# %%
figure,ax = plt.subplots(figsize=(12,6))

sns.countplot(dataset1.work_type)

plt.show()
# Out:
# C:\Users\Rohan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dataset1['Residence_type'].value_counts()
# Out:
# Urban    1814
# Rural    1752
# Name: Residence_type, dtype: int64

# %%
figure,ax = plt.subplots(figsize=(12,6))
dataset1['Residence_type'].value_counts().plot(kind='bar')
plt.show()

# %%
dataset1['smoking_status'].value_counts()
# Out:
# never smoked       1892
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %% [markdown]
# # Bivatiate Analysis

# %%
figure,ax = plt.subplots(figsize=(12,6))
plt.pie(dataset1['smoking_status'].value_counts(),labels=["Never Smoked","Formerly Smoked","Smokes"])
plt.show()

# %%
figure,ax = plt.subplots(figsize=(12,6))
sns.lineplot(x='age',y='bmi', data=dataset1, hue='stroke')
plt.show()

# %%
figure,ax = plt.subplots(figsize=(12,6))
sns.scatterplot(x='age',y='avg_glucose_level', data=dataset1, hue='stroke')
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(dataset1,hue="stroke")

# %%
dataset1.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   3566.000000  3566.000000   3566.000000    3566.000000
# mean   36785.750701    48.853898      0.125070       0.063937
# std    21239.999608    18.874375      0.330845       0.244675
# min       67.000000    10.000000      0.000000       0.000000
# 25%    18042.750000    34.000000      0.000000       0.000000
# 50%    37448.500000    50.000000      0.000000       0.000000
# 75%    54984.250000    63.000000      0.000000       0.000000
# max    72915.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        3566.000000  3566.000000  3566.000000
# mean          108.982011    30.204066     0.056646
# std            48.292204     7.163906     0.231198
# min            55.120000    11.500000     0.000000
# 25%            77.460000    25.400000     0.000000
# 50%            92.650000    28.750000     0.000000
# ...

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3566 entries, 0 to 5108
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3566 non-null   int64
#  1   gender             3566 non-null   object
#  2   age                3566 non-null   float64
#  3   hypertension       3566 non-null   int64
#  4   heart_disease      3566 non-null   int64
#  5   ever_married       3566 non-null   object
#  6   work_type          3566 non-null   object
#  7   Residence_type     3566 non-null   object
#  8   avg_glucose_level  3566 non-null   float64
#  9   bmi                3566 non-null   float64
#  10  smoking_status     3566 non-null   object
#  11  stroke             3566 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 491.2+ KB

# %%
categorical = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
final = pd.get_dummies(dataset1, columns=categorical)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3566 entries, 0 to 5108
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3566 non-null   int64
#  1   age                             3566 non-null   float64
#  2   hypertension                    3566 non-null   int64
#  3   heart_disease                   3566 non-null   int64
#  4   avg_glucose_level               3566 non-null   float64
#  5   bmi                             3566 non-null   float64
#  6   stroke                          3566 non-null   int64
#  7   gender_Female                   3566 non-null   uint8
#  8   gender_Male                     3566 non-null   uint8
#  9   gender_Other                    3566 non-null   uint8
#  10  ever_married_No                 3566 non-null   uint8
#  11  ever_married_Yes                3566 non-null   uint8
# ...

# %%
X = final.drop(['stroke','id'],axis=1)
Y = final['stroke']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3566 entries, 0 to 5108
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             3566 non-null   float64
#  1   hypertension                    3566 non-null   int64
#  2   heart_disease                   3566 non-null   int64
#  3   avg_glucose_level               3566 non-null   float64
#  4   bmi                             3566 non-null   float64
#  5   gender_Female                   3566 non-null   uint8
#  6   gender_Male                     3566 non-null   uint8
#  7   gender_Other                    3566 non-null   uint8
#  8   ever_married_No                 3566 non-null   uint8
#  9   ever_married_Yes                3566 non-null   uint8
#  10  work_type_Govt_job              3566 non-null   uint8
#  11  work_type_Never_worked          3566 non-null   uint8
# ...

# %%
print(Y)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5102    0
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# Name: stroke, Length: 3566, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
print(X_scaled)
# Out:
# [[ 0.96154954 -0.3780856   3.82627115 ...  1.740511   -1.06312135
#   -0.53302866]
#  [ 0.64361365 -0.3780856  -0.26135105 ... -0.57454391  0.94062639
#   -0.53302866]
#  [ 1.65041066 -0.3780856   3.82627115 ... -0.57454391  0.94062639
#   -0.53302866]
#  ...
#  [ 1.70339997 -0.3780856  -0.26135105 ... -0.57454391  0.94062639
#   -0.53302866]
#  [-0.73410858 -0.3780856  -0.26135105 ... -0.57454391  0.94062639
#   -0.53302866]
#  [ 0.11372048 -0.3780856  -0.26135105 ...  1.740511   -1.06312135
#   -0.53302866]]

# %% [markdown]
# # Submission 2

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
import warnings
warnings.filterwarnings("ignore")
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import SMOTE  
from imblearn.pipeline import Pipeline

# %%
# Implementing Random Forest Classifier
# Tuning the random forest parameter 'n_estimators' and implementing cross-validation using Grid Search
model = Pipeline([
        ('balancing', SMOTE(random_state = 101)),
        ('classification', RandomForestClassifier(criterion='entropy', random_state=1) )
    ])
grid_param = {'classification__n_estimators': [10,20,30,40,50,100,150,200]}

#Calling 'recall' score to minimize false negative as in confusion matrix FN needs to reduce. 
gd_sr = GridSearchCV(estimator=model, param_grid=grid_param, scoring='recall', cv=5)

gd_sr.fit(X_scaled, Y)

#Finding best parameter for model
best_parameters = gd_sr.best_params_
print(best_parameters)

# Mean cross-validated score of the best_estimator
best_result = gd_sr.best_score_ 
print(best_result)
# Out:
# {'classification__n_estimators': 30}
# 0.13402439024390245

# %%
# Implementing AdaBoost
# Tuning the AdaBoost parameter 'n_estimators' and implementing cross-validation using Grid Search
model = Pipeline([
        ('balancing', SMOTE(random_state = 101)),
        ('classification', AdaBoostClassifier(random_state=1))
    ])
grid_param = {'classification__n_estimators': [1,2,3,4,5,10,20,30,40,50,100]}

gd_sr = GridSearchCV(estimator=model, param_grid=grid_param, scoring='recall', cv=5)

gd_sr.fit(X_scaled, Y)

#Finding best parameter for model
best_parameters = gd_sr.best_params_
print(best_parameters)

# Mean cross-validated score of the best_estimator
best_result = gd_sr.best_score_ 
print(best_result)
# Out:
# {'classification__n_estimators': 1}
# 0.8221951219512194

# %%
# Implementing Support Vector Classifier
model = Pipeline([
        ('balancing', SMOTE(random_state = 101)),
        ('classification', SVC(random_state=1) )
    ])
grid_param = {'classification__kernel': ['linear','rbf','sigmoid','poly'],'classification__C': [0.0001,.001,.01,.1,1,10,100]}

gd_sr = GridSearchCV(estimator=model, param_grid=grid_param, scoring='recall', cv=5)

gd_sr.fit(X_scaled, Y)

#Finding best parameter for model
best_parameters = gd_sr.best_params_
print(best_parameters)

# Mean cross-validated score of the best_estimator
best_result = gd_sr.best_score_ 
print(best_result)
# Out:
# {'classification__C': 0.0001, 'classification__kernel': 'poly'}
# 1.0
